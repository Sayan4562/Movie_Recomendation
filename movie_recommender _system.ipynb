# %%
import pandas as pd
import numpy as np
import pickle

# %%
data_c=pd.read_csv("movies_data/tmdb_5000_credits.csv")
data_m=pd.read_csv("movies_data/tmdb_5000_movies.csv")

# %%
data_m
# data_m.shape
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
data_m.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %%
data=pd.merge(data_m,data_c)
data.head(3)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4809 entries, 0 to 4808
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4809 non-null   int64
#  1   genres                4809 non-null   object
#  2   homepage              1713 non-null   object
#  3   id                    4809 non-null   int64
#  4   keywords              4809 non-null   object
#  5   original_language     4809 non-null   object
#  6   original_title        4809 non-null   object
#  7   overview              4806 non-null   object
#  8   popularity            4809 non-null   float64
#  9   production_companies  4809 non-null   object
#  10  production_countries  4809 non-null   object
#  11  release_date          4808 non-null   object
#  12  revenue               4809 non-null   int64
#  13  runtime               4807 non-null   float64
#  14  spoken_languages      4809 non-null   object
# ...

# %% [markdown]
# Useing Weighted average for each movie's Average Rating
#
#
# "https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.inchcalculator.com%2Fweighted-average-calculator%2F&psig=AOvVaw1eFYzWipuQzJOJeUgGK4pJ&ust=1713191296492000&source=images&cd=vfe&opi=89978449&ved=0CBIQjRxqFwoTCJCl-53qvoUDFQAAAAAdAAAAABAE"
#
# http://localhost:8888/lab/tree/weighted-average-formula.png

# %%
v=data['vote_count']
r=data['vote_average']
c=data['vote_average'].mean()
m=data['vote_count'].quantile(.70)

# %%
data['weighted_average']=((r*v)+(c*m))/(v+m)

# %%
### Normalize weighted average and Popularity

from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
scal_vale=scaler.fit_transform(data[["weighted_average","popularity"]])
normalize_dataFrame=pd.DataFrame(scal_vale,columns=["weighted_average","popularity"])
data["score"]=normalize_dataFrame["weighted_average"]*0.5 +normalize_dataFrame["popularity"]*0.5
data["score"]
# Out:
# 0       0.423068
# 1       0.370117
# 2       0.279443
# 3       0.450658
# 4       0.218947
#           ...
# 4804    0.221342
# 4805    0.193203
# 4806    0.195151
# 4807    0.192912
# 4808    0.194921
# Name: score, Length: 4809, dtype: float64

# %%
data=data[["movie_id","title","overview","keywords","cast","crew","genres",'score']]

# %%
data.head(2)
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
#
#                                             keywords  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
#
#                                                 crew  \
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
#
#                                               genres     score
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  0.423068
# ...

# %%
data.isnull().sum()
# Out:
# movie_id    0
# title       0
# overview    3
# keywords    0
# cast        0
# crew        0
# genres      0
# score       0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data["genres"][0]
# Out:
# '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'

# %%
import ast
def convert(obj):
    l=[]
    obj=ast.literal_eval(obj)
    for i in obj:
        l.append(i["name"])
    return l

# %%
data["genres"]=data["genres"].apply(convert)

# %%
data["keywords"]=data["keywords"].apply(convert)
data["keywords"][0]
# Out:
# ['culture clash',
#  'future',
#  'space war',
#  'space colony',
#  'society',
#  'space travel',
#  'futuristic',
#  'romance',
#  'space',
#  'alien',
#  'tribe',
#  'alien planet',
#  'cgi',
#  'marine',
#  'soldier',
#  'battle',
#  'love affair',
#  'anti war',
#  'power relations',
#  'mind and soul',
#  '3d']

# %%
def fetch_acter(obj):
    l=[]
    r=0
    obj=ast.literal_eval(obj)
    for i in obj:
        if r!=3:
            r+=1
            l.append(i["name"])
    return l

# %%
data["cast"]=data["cast"].apply(fetch_acter)

# %%
def fetch_director(obj):
    l=[]
    obj=ast.literal_eval(obj)
    for i in obj:
        if i['job']=='Director':
            l.append(i["name"])
    return l

# %%
data["crew"]=data["crew"].apply(fetch_director)
data["crew"]
# Out:
# 0                                [James Cameron]
# 1                               [Gore Verbinski]
# 2                                   [Sam Mendes]
# 3                            [Christopher Nolan]
# 4                               [Andrew Stanton]
#                           ...
# 4804                          [Robert Rodriguez]
# 4805                              [Edward Burns]
# 4806                               [Scott Smith]
# 4807                               [Daniel Hsia]
# 4808    [Brian Herzlinger, Jon Gunn, Brett Winn]
# Name: crew, Length: 4806, dtype: object

# %%
data["overview"]=data["overview"].str.split()

# %%
def ls_st(l):
    r=[]
    for i in l:
        r.append( i.replace(" ",""))
    return r

# %%
data["N_cast"]=data["cast"].apply(ls_st)
data["N_keywords"]=data["keywords"].apply(ls_st)
data["N_crew"]=data["crew"].apply(ls_st)
data["N_genres"]=data["genres"].apply(ls_st)

# %%
data['tag']=data["overview"]+data["N_genres"]+data["N_keywords"]+data["N_cast"]+data["N_crew"]

# %%
nw_data=data[["movie_id","title","tag","score","overview","cast","crew"]]
nw_data["overview"]=nw_data["overview"].apply(lambda x : " ".join(x))

# %%
nw_data["tag"]=nw_data["tag"].apply(lambda x : " ".join(x))

# %%
nw_data["tag"]

# %%
import nltk
from nltk.stem.porter import PorterStemmer
ps=PorterStemmer()

# %%
def stem(text):
    y=[]
    for i in text.split():
        y.append(ps.stem(i))
    return " ".join(y)

# %%
nw_data["tag"]=nw_data["tag"].apply(stem)

# %%
nw_data["score"]

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer(max_features=5000,stop_words="english")

# %%
vactors=cv.fit_transform(nw_data["tag"]).toarray()

# %%
from sklearn.metrics.pairwise import cosine_similarity

similarity=cosine_similarity(vactors)

# %%
similarity[0]

# %%
def marg(list1,list2):
    marge_list=[]
    for i in list1:
        for j in list2:
            marge_list.append([i,j])
    return marge_list

# %%
def recomand(movie):
    movie_index=nw_data[nw_data['title']==movie].index[0]
    distances=similarity[movie_index]
    moive_list=sorted(list(enumerate(distances)),reverse=True,key=lambda x:x[1])[0:11]  ##  lambda x:x[1] use for sort element in bases of second item of list
    ##  enumerate use for marge index and similarity value of every movies 
    for i in moive_list:
        print(nw_data.iloc[i[0]].title)

# %%
recomand('Spectre')

# %%
pickle.dump(nw_data.to_dict(),open('movie_dict.pkl','wb'))

# %%
pickle.dump(similarity,open('similarity.pkl','wb'))

# %%
nw_data
# Out:
#       movie_id                                     title  \
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4804      9367                               El Mariachi
# 4805     72766                                 Newlyweds
# 4806    231617                 Signed, Sealed, Delivered
# 4807    126186                          Shanghai Calling
# 4808     25975                         My Date with Drew
#
#                                                     tag     score  \
# 0     [In, the, 22nd, century,, a, paraplegic, Marin...  0.423068
# 1     [Captain, Barbossa,, long, believed, to, be, d...  0.370117
# 2     [A, cryptic, message, from, Bond’s, past, send...  0.279443
# ...
